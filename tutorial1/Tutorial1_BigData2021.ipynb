# %% [markdown]
# ## Dato numéricos, de texto y booleanos

# %% [markdown]
# Enteros (o integer): son valores numéricos enteros, positivos o negativos, de longitud ilimitada.

# %%
4
# Out:
# 4

# %%
type(4)
# Out:
# int

# %%
poblacion_arg = 44940000
type(poblacion_arg)
# Out:
# int

# %%
type(-785)
# Out:
# int

# %% [markdown]
# ## Booleano

# %% [markdown]
# De coma flotante (float): son valores numéricos con decimales, positivos o negativos. En su versi\'on nativa guarda hasta 16 lugares decimales.

# %%
print(type(4.655))
print(type(135456354.655))
type(-4.5)
# Out:
# <class 'float'>
# <class 'float'>
# float

# %% [markdown]
# Caracteres: son valores enmarcados entre ' ' o " ". Al estar enmarcados, los valores son interpretados como texto (y no como números u operadores aritméticos).

# %%
\begin{lstlisting}[language=Python]
e)
\end{lstlisting}

\end{frame}

\begin{frame}[fragile, t]
\frametitle{Dato de Texto}
\textbf{
\begin{lstlisting}[language=Python]
"A"
"t"
"r"
"123"
\end{lstlisting}
\bigskip

\textbf{Cadenas de Caracteres:} o \emph{string} son una sucesión de caracteres enmaracdos entre ' ' o " ".  
\begin{lstlisting}[language=Python]
"Hello World!"
"Nos, los representantes del pueblo de la"
\end{lstlisting}

\end{frame}

\begin{frame}[fragile, t]
\frametitle{}
\textbf{Lógico:} o \emph{booleano} son expresiones que se evalúan a ser ciertas o no, es decir, adoptan uno de dos valores: TRUE o FALSE.

\begin{lstlisting}[language=Python]
>>> "texto" == "texto"
True 
>>> "texto" != "texto"
False 
>>> 256 < 76
False
>>> 256 >= 76
True
>>> 256 >= 256
True
\end{lstlisting}

\end{frame}

\begin{frame}[fragile, t]
\frametitle{Tipos de datos: preguntas}
Ahora veamos algunas preguntas para asentar estas definiciones. Abran una consola o un Jupyter Notebook y prueben lo siguiente para poder responder las preguntas. \newline

¿Es equivalente un número escrito como entero o en formato de coma flotante? ¿Y si está escrito cómo string? Prueben lo siguiente: \newline

\begin{lstlisting}[language=Python]
>>> 17 == 17.0
>>> -750.0 != -750
>>> 121 == 121.0001
>>> 524 == "524"
\end{lstlisting}

\end{frame}

\begin{frame}[fragile, t]
\frametitle{Tipos de datos: preguntas II}

¿Los strings, o cadena de caracteres, son sensibles al uso de " " o ' '? Prueben lo siguiente: \newline

\begin{lstlisting}[language=Python]
>>> "Argentina" == 'Argentina'
>>> 'programa' != "programa"
\end{lstlisting}
\bigskip
¿Los strings, o cadena de caracteres, son sensibles al uso de mayúsculas y minúsculas? Prueben lo siguiente: \newline

\begin{lstlisting}[language=Python]
>>> "Argentina" == "ARGENTINA"
>>> 'universidad' == "uNiVeRsIdAd"
\end{lstlisting}

\end{frame}

\section{Operaciones básicas}

\begin{frame}[fragile, t]
\frametitle{Operaciones básicas}
Ahora veamos algunas operaciones básicas! \newline

\textbf{Sumar y Restar:}
\begin{lstlisting}[language=Python]
>>> 100 + 48
148
>>> 100.5 - 12.3
88.2
\end{lstlisting} \bigskip

\textbf{Multiplicar y Dividir:}
\begin{lstlisting}[language=Python]
>>> 10.1 * 3
30.3
>>> 80 / 4
20.0
>>> 5 / 2
2.5
\end{lstlisting} \smallskip

\emph{Nota: división entre enteros da como resultado un float en Python 3.x. En versiones anteriores resultaba en un entero.}

\end{frame}

\begin{frame}[fragile, t]
\frametitle{Operaciones básicas II}

\textbf{Exponencial:}
\begin{lstlisting}[language=Python]
>>> 12**2
144
\end{lstlisting} \medskip

\textbf{Cociente de una división:}
\begin{lstlisting}[language=Python]
>>> 10.0 // 4
2
\end{lstlisting} \medskip

\textbf{Módulo:}
\begin{lstlisting}[language=Python]
>>> 5 % 2
1
>>> 10 % 4
2
>>> 4.5 % 4
0.5
\end{lstlisting}
\emph{Nota: en breve veremos un caso dónde esto es útil.}

\end{frame}

\begin{frame}[fragile, t]
\frametitle{Operaciones con strings}
Con \emph{strings} tambi\'en podemos hacer algunas operaciones \newline

\textbf{Concatenar (sumar):}
\begin{lstlisting}[language=Python]
>>> "Esto es " + "concatenar dos strings"
"Esto es concatenar dos strings"
>>> "a" + "bb" + "ccc"
"abbccc"
\end{lstlisting} \bigskip

\textbf{Repetir (multplicar):}
\begin{lstlisting}[language=Python]
>>> 'a'*3
'aaa'
>>> 'Muy bueno!'*2
'Muy bueno!Muy bueno!'
\end{lstlisting}
\end{frame}

\section{Operadores lógicos}


\begin{frame}[fragile, t]
\frametitle{Operadores lógicos}
\textbf{Operadores lógicos:} son \emph{and}, \emph{or} y \emph{not} y dan como resultados un valor booleano (True o False). \newline 

\bigskip
Van a ser particularmente útiles para las sentencias condicionales.

\begin{lstlisting}[language=Python]
>>> 4 < 7 and 4 > 1
True
>>> 4 == 1 or 4 > 1
True
>>> 4 == 1 or 4 > 9
False
>>> not (4 == 1)
True

\end{lstlisting} \bigskip

\end{frame}

\section{Interludo: definición de variables}

\begin{frame}[fragile, t]
\frametitle{Variables}
\textbf{Variable:} Son objetos con un \emph{identificador} (nombre) y un contenido asociados. En Python son fáciles de definir, se hace así:

\begin{lstlisting}[language=Python]
>>> mivariable = "a"
>>> print(mivariable)
"a"
>>> a = 100
>>> b = 17
>>> print(a + b)
117
\end{lstlisting} \bigskip

Es una buena práctica que los nombres de las variables tengan un sentido asociado a su contenido.

\begin{lstlisting}[language=Python]
>>> nombre_universidad = "Universidad Nacional de La Plata"
>>> print(nombre_universidad)
"Universidad Nacional de La Plata"
\end{lstlisting} \bigskip

\end{frame}

\begin{frame}[fragile, t]
\frametitle{Variables: restricciones}
Hay algunas consideraciones a tenern en cuenta respecto a los nombres que se pueden utilizar al definir una variable:

\begin{itemize}
    \item Es sensible al uso de mayúsculas/minúsculas (no son intercambiables).
    \item Solo puede contener valores alfanúmericos o "\_"
    \item No puede comenzar con un caracter numérico
\end{itemize}
\medskip
Algunas buenas prácticas son:
\begin{itemize}
    \item siempre minusculas a menos que sea una constante (global en stata)
    \item se usa snake\_case y no  CamelCase
    \item no usar caracteres latinos (ej:  ”ó”,”ñ”, ”ü”, etc.). 
\end{itemize} 

\end{frame}

\begin{frame}[fragile, t]
\frametitle{Operaciones y variables: preguntas}

Vimos que el operador "+" se puede usar para valores numéricos y para strings. ¿Se puede usar para una combinación de ambos?

\begin{lstlisting}[language=Python]
>>> 12 + "34"
\end{lstlisting} 

Al nombrar dos variables de manera similar pero modificando mayúsculas/minúsculas, ¿estamos creando dos variables o pisando el valor de la primera con el valor de la segunda? \emph{Prueben creando ambas variables y luego imprimiendo sus valores.} 

\begin{lstlisting}[language=Python]
>>> resultado = "a"
>>> RESULTADO = "b"
\end{lstlisting} 

¿Alguno de estos nombres de variable es válido?
\begin{lstlisting}[language=Python]
>>> 2variable = "a"
>>> mi-variable = "a"
>>> mi__var_iab_ = "a"
\end{lstlisting} 

\end{frame}

\section{Colecciones: Listas, Tuplas, Sets y Diccionarios}

\begin{frame}[fragile]
\frametitle{¿Que son las colecciones?}
Una colección en python es un container que permite agrupar objetos y darles un nombre. \newline

Ej. Lista de código de paises:

\begin{lstlisting}[language=Python]
>>> paises = ['ARG', 'BOL', 'BRA', 'CHL', 'PRY', 'URY']
\end{lstlisting}

Hoy vamos a ver los cuatro tipos de colleciones nativas de python: listas, diccionarios, sets y tuplas. \newline
\newline
¿Porqué tantos tipos de colecciones? 
\begin{itemize}
    \item Ordenadas vs. sin orden
    \item Valores repetidos vs. valores unicos
    \item Mutables vs. inmutables
\end{itemize}

\end{frame}

%\section{Listas}

\begin{frame}[fragile]
\frametitle{Listas}
Es una secuencia \textbf{ordenada}, \textbf{mutable} de \textbf{distintos tipos} de elementos \newline

# %al ser ordenada veremos que se puede indexar para acceder a cada elemento en la posicion que los pusimos
% al ser mutable veremos que podemos agregar, quitar y cambiar elementos de la lista.
# %Las listas se pueden utilizar para cualquier tipo de objeto, desde números y cadenas hasta más list

\begin{itemize}
    \item ¿Cómo definir una lista? con [ ]
\begin{lstlisting}[language=Python]
>>> paises = ['ARG', 'BOL', 'BRA', 'CHL', 'PRY', 'URY']
>>> pob_m = [44939, 11513, 211050, 18952, 7045.5, 3462] 
\end{lstlisting}
% a paraguay le pusimos la poblacion con decimales, lo que quiere decir que ese numero estará almacenado como un float, mientras que los demas numeros serán int.
%>>> list(range(5))
%>>> print(lista1)
%[0, 1, 2, 3, 4]
\item ¿ saber el largo de una lista? len( )
\begin{lstlisting}
>>> len(paises)     
6
\end{lstlisting}
\item ¿Cómo acceder a un elemento? indexando (desde 0 a N o -1). 
\begin{lstlisting}
>>> paises[0]
'ARG' 
>>> pob_m[-1]
3462
\end{lstlisting}
\end{itemize}
\end{frame}

\begin{frame}[fragile]
\frametitle{Listas}
\begin{itemize}
\item ¿Cómo acceder a un sub-conjunto de elementos? 
# %si selecciono [4:] tendré desde el 4to elemento, que es aquel en la pocision 0, hasta el de la pocision 2 sin incluir.
# %si selecciono [:3] tendré desde el 1er elemento, que es aquel en la pocision 0, hasta el de la pocision 3 sin incluir.

# %la pocision 4 en [2:4] no estará incluida en la seleccion
\begin{lstlisting}[language=Python]
>>> paises[:]
['ARG', 'BOL', 'BRA', 'CHL', 'PRY', 'URY']
>>> paises[4:] 
['PRY', 'URY'] 
>>> paises[:3]
['ARG', 'BOL', 'BRA'] 
>>> paises[2:-2]  #equivalente a  paises[2:4] 
['BRA', 'CHL']
\end{lstlisting}
    \item ¿Cómo modificar un elemento? 
\begin{lstlisting}[language=Python]
>>> pob_m[-2] = 7045
>>> print(pob_m)
[44939, 11513, 211050, 18952, 7045, 3462]
\end{lstlisting}
\end{itemize}

\end{frame}

\begin{frame}[fragile]
\frametitle{Listas: métodos básicos}
\begin{itemize}
    \item Agregar objetos: append, insert.
    \begin{lstlisting}[language=Python]
>>> paises.append('PER') 
>>> pob_m.insert(-1, 31989) 
>>> print(paises[-1], '--> poblacion:', pob_m[-1])
PER  poblacion: 3462
\end{lstlisting}
    \item Unir listas: extend %cada elemento de un iterable se agrega
    \begin{lstlisting}[language=Python]
>>> paises2 = ['COL', 'ECU', 'GUY', 'SUR', 'TTO', 'VEN']
>>> paises.extend(paises2)
>>> print(paises)
['ARG', 'BOL', 'BRA', 'CHL', 'PRY', 'URY', 'PER', 'COL', 'ECU', 'GUY', 'SUR', 'TTO', 'VEN']
\end{lstlisting}
    \item Eliminar objetos: remove, del, pop. 
# %remove elimina la primera ocurrencia del valor indicado
# %pop elimina el elemento en la pocision indicada y devuelve el valor. Si quisiera puedo guardar el valor indicandole un nombre de variable donde almacenarlo = paises.pop(-1) y si no lo quiero guardar, solo hago paises.pop(-1) y me lo va a imprimir, me va a devovler ese valor que saco de mi lista. 
# %por ultimo con del tambien puedo sacar un elemento por su pocision, pero la direfecnai con pop es que no me devolverá el valor. En este ejemplo vamos a remover todos los paises que agregamos, que no son limitrofes de Argentina,  y para los cuales no teniamos la poblacion en nuetra otra lista.
\begin{lstlisting}[language=Python]
>>> paises.remove('COL')
>>> paises.pop(-1)
'VEN'
>>> del paises[-4:]

\end{lstlisting}
\end{itemize}
\end{frame}


\begin{frame}[fragile]
\frametitle{Listas: copias y referencias}
\begin{itemize}
# %Copia independiente o referencia a otra lista
# %Al definirlas con igual, lo que cree fue una referencia, es decir que cuando modifico paises_sa, voy a estar modificando tambien paises2 y viceversa.
# %En cambio, cuando le esplico que quiero una copia independiente, tengo que usar copy() o [:]
    \item ¿Cómo hacer una referencia de una lista?
    \begin{lstlisting}[language=Python]
>>> paises2 = ['COL', 'ECU', 'GUY', 'SUR', 'TTO', 'VEN']
>>> paises_sa = paises2
>>> paises_sa.append('ARG')
>>> print(paises_sa)
['COL', 'ECU', 'GUY', 'SUR', 'TTO', 'VEN', 'ARG']
>>> print(paises2)
['COL', 'ECU', 'GUY', 'SUR', 'TTO', 'VEN', 'ARG']
\end{lstlisting}
\item Sí no era esto lo que queriamos, saquemos ARG y hagamos una copia independiente de la lista:
\begin{lstlisting}
>>> paises2.remove('ARG')
\end{lstlisting}
\end{itemize}
\end{frame}


\begin{frame}[fragile]
\frametitle{Listas: copias y referencias}
\begin{itemize}
# %Copia independiente o referencia a otra lista
# %Al definirlas con igual, lo que cree fue una referencia, es decir que cuando modifico paises_sa, voy a estar modificando tambien paises2 y viceversa.
# %En cambio, cuando le esplico que quiero una copia independiente, tengo que usar copy() o [:]
# %cuando se copia una lista en una variable, se copia una referencia 
    \item ¿Cómo copiar una lista?
    \begin{lstlisting}[language=Python]
>>> paises_sa = paises2.copy() # equivalente a: paises_sa = paises2[:]
>>> paises_sa.extend(paises)
>>> print(paises2)
['COL', 'ECU', 'GUY', 'SUR', 'TTO', 'VEN', 'PER']
>>> paises_sa
['COL', 'ECU', 'GUY', 'SUR', 'TTO', 'VEN', 'ARG', 'BOL', 'BRA', 'CHL', 'PRY', 'URY', 'PER']
\end{lstlisting}
\end{itemize}
\end{frame}


\begin{frame}[fragile]
\frametitle{Listas: iteraciones}
\begin{itemize}

\item ¿Cómo iterar sobre una lista? 
\begin{lstlisting}[language=Python]
>>> pob_tot = 0
>>> for pob in pob_m:
>>>     pob_tot += pob
print(pob_tot)
296961
\end{lstlisting}


\begin{lstlisting}[language=Python]
>>> for n, pais in enumerate(paises):
>>>     print(pais, ': ', pob_m[n])
ARG: 44939
BOL: 11513
BRA: 211050
CHL: 18952
PRY: 7045
URY: 3462
\end{lstlisting}
\end{itemize}
\end{frame}



\begin{frame}[fragile]
\frametitle{Listas: pregunta}
\begin{itemize}

\item ¿Cuál es el resultado de sumar la lista de paises con la lista de población? 
\begin{lstlisting}[language=Python]
>>> paises + pob_m
???
\end{lstlisting}
\begin{lstlisting}[language=Python]
>>> paises.append(pob_m)
>>> ['ARG', 44939, 'BOL', 11513, 'BRA', 211050, 'CHL', 18952, 'PRY', 7045, 'URY', 3462]
>>> paises.extend(pob_m)
\end{lstlisting}
 

\end{itemize}
\end{frame}


%\section{Tuplas}

\begin{frame}[fragile]
\frametitle{Tuplas}
Es una secuencia \textbf{ordenada}, \textbf{inmutable} de \textbf{distintos tipos} de elementos. Se utilizan para mantener juntos varios objetos. \newline 
% al ser inmutable veremos que tienen menos metodos que las listas. 
# %Lo que si podemos hacer es reemplazar una tupla con una nueva que lleve el mismo nombre.

% al ser ordenada veremos que se puede indexar igual que las listas para acceder a cada elemento en la posicion que los pusimos

\begin{itemize}
    \item ¿Cómo definir una tupla? con ( )
\begin{lstlisting}[language=Python]
>>> argentina = ('ARG', 44939)
>>> bolivia = ('BOL', 11513)
>>> brasil = ('BRA', 211050)
\end{lstlisting}

\item ¿Cómo modificar, agregar o eliminar un elemento? No se puede.
\begin{lstlisting}[language=Python]
>>> argentina[0] = 'ARGEN'
Traceback (most recent call last):
  File "<stdin>", line 1, in <module>
TypeError: 'tuple' object does not support item assignment
\end{lstlisting}
\begin{lstlisting}[language=Python]
>>> argentina = ('ARG', 44939, 22947)
>>> bolivia = ('BOL', 11513, 9086)
>>> brasil = ('BRA', 211050, 15259)
\end{lstlisting}
\end{itemize}
\end{frame}


\begin{frame}[fragile]
\frametitle{Tuplas: indices}
\begin{itemize}
\item ¿Cómo saber el largo de una tupla? len( )
\begin{lstlisting}[language=Python]
>>> len(brasil)     
3
\end{lstlisting}
\item ¿Cómo acceder a un elemento? indexando (desde 0 a N o -1). 
\begin{lstlisting}[language=Python]
>>> bolivia[0]
'BOL' 
>>> bolivia[1] #equivalente a bolivia[-2] 
11513
\end{lstlisting}
\item ¿Cómo acceder a un sub-conjunto de elementos? Igual a listas
\begin{lstlisting}[language=Python]
>>> argentina[:]
('ARG', 44939, 22947)
>>> argentina[1:] 
(44939, 22947)
>>> argentina[:2] #equivalente a  argentina[:-1] 
('ARG', 44939)
\end{lstlisting}
\end{itemize}
\end{frame}
# %A diferencia de la lista, cuando se copia una tupla se copia el contenido.

# %TUPLAS
# %Method	Description
# %count()	Returns the number of times a specified value occurs in a tuple
# %index()	Searches the tuple for a specified value and returns the position of where it was found
# %Loops and check if in tuple. 

%\section{Sets}
\begin{frame}[fragile]
\frametitle{Conjuntos (sets)}
Es una secuencia \textbf{no ordenada}, \textbf{mutable} de \textbf{distintos tipos} de elementos \textbf{no repetidos}. \newline 
\begin{itemize}
    \item ¿Cómo definir un set? con set([ ])
# %el set se define con set() y dentro del parentesis vamos a poner una lista. podemos escribirla, como aprendimos antes, corchetes y separando con comas, o podemos directamente poner una lista que ya teniamos definida, como la lista que llamamos paises. Y si en esa lista en algun momento hubieramos cometido el error de volver a agregar un codigo de pais que ya estaba, al crear un set con esos datos, se eliminaria los valores repetidos dejando codigos UNICOS de paises. 
# %Y como veran, al imprimirlo, lo vemos entre corchetes {}. Esto me parece importante que lo puedan ver, y lo sepan distinguir luego de los diccionarios que veremos a continuacion. 
\begin{lstlisting}[language=Python]
>>> chl_limit = set(['ARG', 'BOL', 'PER'])
>>> arg_limit = set(paises)
>>> print(arg_limit)
{'URY', 'BOL', 'ARG', 'CHL', 'PRY', 'BRA'}
>>> type(arg_limit)
<class 'set'>

\end{lstlisting}
\item ¿Cómo saber el largo de un set? len( )
\begin{lstlisting}[language=Python]
>>> len(chl_limit)     
3
\end{lstlisting}
\end{itemize}
\end{frame}

\begin{frame}[fragile]
\frametitle{Sets: no ordenados}
\begin{itemize}
\item No se puede acceder ni modificar un elemento 
\begin{lstlisting}[language=Python]
>>> chl_limit[:]
Traceback (most recent call last):
  File "<stdin>", line 1, in <module>
TypeError: 'set' object is not subscriptable
\end{lstlisting}
\begin{lstlisting}[language=Python]
>>> chl_limit[-2] = 'AAA'
Traceback (most recent call last):
  File "<stdin>", line 1, in <module>
TypeError: 'set' object does not support item assignment
\end{lstlisting}
\end{itemize}
\end{frame}


\begin{frame}[fragile]
\frametitle{Sets: métodos básicos}
\begin{itemize}
    \item Agregar objetos: add()
    \begin{lstlisting}[language=Python]
>>> arg_limit.add('ARG') 
>>> chl_limit.add('CHL') 
\end{lstlisting}
    \item Unir dos sets: union() 
    \begin{lstlisting}[language=Python]
>>> ar_cl_limit = arg_limit.union(chl_limit)
>>> print(ar_cl_limit)
{'URY', 'BOL', 'ARG', 'CHL', 'PER', 'PRY', 'BRA'}

\end{lstlisting}
    \item Eliminar objetos: remove, del, pop. 
# %remove elimina la primera ocurrencia del valor indicado
# %pop elimina el elemento en la pocision indicada y devuelve el valor. Si quisiera puedo guardar el valor indicandole un nombre de variable donde almacenarlo = paises.pop(-1) y si no lo quiero guardar, solo hago paises.pop(-1) y me lo va a imprimir, me va a devovler ese valor que saco de mi lista. 
# %por ultimo con del tambien puedo sacar un elemento por su pocision, pero la direfecnai con pop es que no me devolverá el valor. En este ejemplo vamos a remover todos los paises que agregamos, que no son limitrofes de Argentina,  y para los cuales no teniamos la poblacion en nuetra otra lista.
\begin{lstlisting}[language=Python]
>>> arg_limit.remove('ARG') 
>>> chl_limit.discard('CHL')
>>> arg_limit.pop() 
'URY'
#volvamos a agregarlo: >>> arg_limit.add('URY') 
\end{lstlisting}
# %El metodo discard es similar que remove pero difieren en que si el elemento que se le pasa a remove no existe en el set, entonces se elevará un error. en cambio con discard no se emite un error.
# %el metodo pop para sets no admite ningun argumento, esto quiere decir que no se puede agregar nada dentro del parentesis. y lo que hace es eliminar un elemento al azar y te lo devuelve. 
\end{itemize}
\end{frame}


\begin{frame}[fragile]
\frametitle{Sets: otros métodos}
\begin{itemize}
\item ¿Cómo saber la interseccion y las diferencias de dos sets?
    \begin{lstlisting}[language=Python]
>>> arg_limit.difference(chl_limit)
{'CHL', 'URY', 'BRA', 'PRY'}
>>> arg_limit.intersection(chl_limit)
{'BOL'}
\end{lstlisting}
\item ¿Cómo si in set es subset de otro o disjunto?
\begin{lstlisting}[language=Python]
>>> chl_limit.issubset(arg_limit)
False
>>> chl_limit.isdisjoint(arg_limit)
False
\end{lstlisting}
\end{itemize}
\end{frame}



\begin{frame}[fragile]
\frametitle{Sets: copias y referencias}
\begin{itemize}
\item ¿Cómo hacer una referencia de un set?
    \begin{lstlisting}[language=Python]
>>> pry_limit = arg_limit
>>> pry_limit.remove('CHL')
>>> arg_limit
{'URY', 'BOL', 'PRY', 'BRA'}
\end{lstlisting}
\begin{lstlisting}
>>> arg_limit.add('CHL') #primero agreguemos Chile
\end{lstlisting}
\item  ¿Cómo hacer una copia independiente del set?
\begin{lstlisting}[language=Python]
>>> pry_limit = arg_limit.copy()  
>>> pry_limit.remove('CHL')
>>> arg_limit
{'URY', 'BOL', 'CHL', 'PRY', 'BRA'}
\end{lstlisting}
\end{itemize}
\end{frame}

\begin{frame}[fragile]
\frametitle{Sets y Tuplas: pregunta}
\begin{itemize}
\item ¿El valor de temp1 y temp2 será el mismo?
    \begin{lstlisting}[language=Python]
>>> pry_limit
{'URY', 'BOL', 'PRY', 'BRA'}
>>> temp1 = pry_limit.remove('URY')
>>> temp2 = pry_limit.pop()
    \end{lstlisting}
\item ¿Cual es un posible valor de temp2?
    \begin{lstlisting}[language=Python]
a) {'URY', 'BOL', 'PRY'}
b) {'BOL', 'PRY'} 
c) 'URY'
d) 'BRA'
    \end{lstlisting}
\end{itemize}
\end{frame}



%\section{Diccionarios}
\begin{frame}[fragile]
\frametitle{Diccionarios}
Los diccionarios son conjuntos de \textbf{claves:valores} (key:values). Las claves deben ser \textbf{únicas y hasheables}. Los \textbf{valores se pueden modificar} pero las claves no.  \newline
# %esto quiere decir que no cualquier cosa puede ser una clave. Nesitamos que sea un objeto inmutable. Ya hemos visto por ej. que las tuplas son inmutables. es decir que podriamos usar nuestra variable argentina, como clave. Pero las listas no son inmutables, es decir que no podriamos usar nuestra variable paises como clave.  

# %Pares (clave, valor). Cómo definir un diccionario, cómo iterar, chequear contenido, etc.

%['ARG', 'BOL', 'BRA', 'CHL', 'PRY', 'URY']
%>>> pob_m = [44939, 11513, 211050, 18952, 7045.5, 3462] 

\begin{itemize}
    \item ¿Cómo definir un diccionario? con \{ \}
\begin{lstlisting}[language=Python]
>>> arg_carac = {'cod': 'ARG', 'pob': 44939, 'gdp': 'N'}
>>> bol_carac = {'cod': 'BOL', 'pob': 11513, 'gdp': 'N'}
>>> print(bol_carac)
{'cod': 'BOL', 'pob': 11513, 'gdp': 'N'}
\end{lstlisting}
\item ¿ saber el largo de un diccionario? len( )
\begin{lstlisting}[language=Python]
>>> len(bol_carac) #equivalente a len(bol_carac.items())     
3
\end{lstlisting}

\end{itemize}
\end{frame}



\begin{frame}[fragile]
\frametitle{Diccionarios}
\begin{itemize}
\item ¿Cómo acceder a un elemento? por la clave 
\begin{lstlisting}[language=Python]
>>> bol_carac['cod']
'BOL'
>>> arg_carac['pob']
44939
\end{lstlisting}
\item ¿Cómo cambiar un valor?  
\begin{lstlisting}[language=Python]
>>> arg_carac['gdp'] = 1031215
>>> bol_carac['gdp'] = 104609
\end{lstlisting}
\item ¿Cómo crear una nueva clave:valor?  
\begin{lstlisting}[language=Python]
>>> arg_carac['gdp_pc'] = arg_carac['gdp']/
                          arg_carac['pob']*100
\end{lstlisting}
\item ¿Cómo borrar una clave:valor?  
\begin{lstlisting}[language=Python]
>>> dic_pais.pop("gdp_pc") 
\end{lstlisting}

\end{itemize}
\end{frame}


\begin{frame}[fragile]
\frametitle{Diccionarios: metodos básicos}
\begin{itemize}
\item ¿Cómo saber las claves o valores de un diccionario?  
\begin{lstlisting}[language=Python]
>>> bol_carac.keys() 
dict_keys(['cod', 'poblacion', 'gdp'])

>>> bol_carac.values()
dict_values(['BOL', 11513, 104609])

>>> bol_carac.items()
dict_items([('cod', 'BOL'), 
            ('poblacion', 11513), 
            ('gdp', 104609)])
\end{lstlisting}
item ¿Cómo saber si una clave esta en un diccionario?  
\begin{lstlisting}[language=Python]
>>> 'cod' in bol_carac.keys() 
True
\end{lstlisting}
\end{itemize}
\end{frame}


\begin{frame}[fragile]
\frametitle{Diccionarios}
\begin{itemize}

\item ¿Cómo obtener un valor cuando no se si la clave existe?  
\begin{lstlisting}[language=Python]
>>> arg_carac["gdp_pc"] 
22946.99481519393

>>> bol_carac["gdp_pc"] 
Traceback (most recent call last):
  File "<stdin>", line 1, in <module>
KeyError: 'gdp_pc'
\end{lstlisting}
\begin{lstlisting}[language=Python]
>>> bol_carac.get("gdp_pc", 'No value') 
'No value'
\end{lstlisting}
# %equivalente a  dic_pais.setdefault

\end{itemize}
\end{frame}


\begin{frame}[fragile]
\frametitle{Diccionarios}
\begin{itemize}

\item ¿Cómo crear un diccionario con los datos de una lista?  
\begin{lstlisting}[language=Python]
>>> print(paises)
['ARG', 'BOL', 'BRA', 'CHL', 'PRY', 'URY']
>>> info_paises = dict.fromkeys(paises, "")
>>> info_paises
{'ARG': '', 'BOL': '', 'BRA': '', 'CHL': '', 'PRY': '', 'URY': ''}
\end{lstlisting}
\begin{lstlisting}[language=Python]
>>> print(pob_m)
[44939, 11513, 211050, 18952, 7045, 3462]
>>> poblacion = dict(zip(paises, pob_m))
>>> poblacion
{'ARG': 44939, 'BOL': 11513, 'BRA': 211050, 'CHL': 18952, 'PRY': 7045, 'URY': 3462}
\end{lstlisting}
\end{itemize}
\end{frame}



\begin{frame}[fragile]
\frametitle{Diccionarios}
\begin{itemize}
    \item Un diccionario puede ser valor de otro diccionario
    # %ya tenemos un diccionario para las caracteristicas de argentina y de bolivia
\begin{lstlisting}[language=Python]
>>> bra_carac = {'cod':'BRA','pob':211050,'gdp':3220373}
>>> chl_carac = {'cod':'CHL', 'pob':18952, 'gdp':476738}
>>> pry_carac = {'cod':'PRY', 'pob':7045, 'gdp':93062}
>>> ury_carac = {'cod':'URY', 'pob':3462, 'gdp':77732}

>>> paises_info = { 'argentina': arg_carac, 
                    'bolivia': bol_carac, 
                    'brasil': bra_carac, 
                    'chile': chl_carac, 
                    'paraguay': pry_carac, 
                    'uruguay': ury_carac}
                    
>>> paises_info['brasil']['gdp]
3220373
\end{lstlisting}
\end{itemize}
\end{frame}

\begin{frame}[t]
\frametitle{Resumen}
\begin{table}[h!]
\tiny{\caption{Resumen de colecciones}}
\label{table:2J}
\begin{center}
\begin{tabular}{m{1.65cm} m{1.6cm} m{1.6cm} m{1.6cm} m{1.6cm} m{1.6cm}} 
\hline
& Listas & Tuplas  & Sets & Diccionarios\\ 
 \hline\hline
Se definen con & [ ]  & ( )  & set() & \{ \}\\
Ordenados & Si & Si & No & No \\
Inmutables & No & Si & No & keys: Si, values: No\\
Elementos unicos & No & No & Si & keys: Si, values: No\\
\multirow{Usos} & Para colecciones & Para datos que no & Para chequear per- & Para asociaciones\\
& simples, iterables & van a cambiar. & tenencia y eliminar & lógicas de key:value\\
& que se modifican & Puede ser la key de & duplicados. Para & Para busquedas \\
& seguido & un diccionario. & elementos unicos. & rápidas\\
\hline\hline 
\end{tabular}
\end{center}
\end{table}
\end{frame}


\begin{frame}[fragile]
\frametitle{Diccionarios: pregunta}
\begin{itemize}
\item ¿Que pasa si intento crear un set de un diccionario?
\begin{lstlisting}[language=Python]
>>> set_arg_carac = set(arg_carac)
>>> print(set_arg_carac)

a) error
b) {'cod', 'pob', 'gdp'}
c) {'cod', 'ARG', 'pob', 44939, 'gdp', 1031215}
d) {'arg_carac'}

\end{lstlisting}

\end{itemize}
\end{frame}

\section{Sentencias condicionales y ciclos}

\begin{frame}[fragile, t]
\frametitle{Sentencias}
Una sentencia es un instrucción que el intérprete de Python puede ejecutar. Ya vimos dos tipos de sentencia. \newline

\textbf{Sentencia de asignación:} es la que usamos para definir una variable. \newline

\begin{lstlisting}[language=Python]
>>> pais = "Argentina"
\end{lstlisting} 
\bigskip

Esta sentencia no arroja un resultado visible; usamos la sentencia \emph{print} para visualizar el resultado. \newline

\begin{lstlisting}[language=Python]
>>> pais = "Argentina"
>>> print(pais)
"Argentina"
\end{lstlisting} 
\bigskip

\end{frame}

\begin{frame}[fragile, t]
\frametitle{Sintáxis}
Algunas reglas y recomendaciones sobre la sintáxis. \newline

1. Es importante comentar el código! Para comentar código utilizamos "\#". Todo lo que esté a la derecha de ese caracter sobre la misma línea va ser interpretado cómo un comentario.
\begin{lstlisting}[language=Python]
>>> pais = "Argentina"   # identifico pais a analizar
>>> # verificamos asignacion correcta
>>> print(pais)
"Argentina"
\end{lstlisting} 
\smallskip

2. La indentación (sangría) juega un papel fundamental en la declaraciones de sentencias condicionales (veremos a continuación).

\end{frame}

\begin{frame}[fragile, t]
\frametitle{Bucles: for loop}
\textbf{Bucle}: o \emph{loop} es cuando usamos una sentencia para indicarle al intérprete que repita una serie de instrucciones hasta que se deje de cumplir una regla definida. \newline

\textbf{for loop}: para cada X de Y, hacer Z.\newline

\begin{lstlisting}[language=Python]
>>> # armo una lista de paises
>>> lista_paises = ["Argentina", "Bolivia", "Chile"]   
>>> # construyo un for loop
>>> for pais in lista_paises:  # el ":" es necesario
>>>     print("Nombre: " + pais) # la sangria es necesaria
"Nombre: Argentina"
"Nombre: Bolivia"
"Nombre: Chile"
\end{lstlisting}

\end{frame}

\begin{frame}[fragile, t]
\frametitle{Bucles: while loop}

\textbf{while loop}: mientras X cumpla condición Y, hacer Z.\newline

\begin{lstlisting}[language=Python]
>>> # defino cupo máximo
>>> cupos_libres = 3
>>> # ahora el while loop
>>> while cupos_libres > 0:
>>>     print('Inscripcion acceptada')
>>>     cupos_libres = cupos_libres - 1
>>> print('Cupo lleno') # esta linea esta fuera del loop
Inscripcion aceptada
Inscripcion aceptada
Inscripcion aceptada
Cupo lleno

\end{lstlisting}

\end{frame}

\begin{frame}[fragile, t]
\frametitle{Control de flujo}
Usamos sentencias condicionales para construir programas (scripts) que respondan a condiciones predefinidas.\newline

\textbf{sentencia condicional}: if A, X, elif B, Y, else C, Z.\newline

\begin{lstlisting}[language=Python]
>>> edad = 25   
>>> # aca empieza la sentencia condicional
>>> if edad < 18: # el ":" es importante
>>>     print("Menor de edad") # atencion a la sangria
>>> elif edad >= 18:  # atencion a la sangria y ":"
>>>     print("Mayor de edad")  # atencion a la sangria
>>> else:
>>>     print("Revisar input!")
Mayor de edad
\end{lstlisting} 

\end{frame}

\begin{frame}[fragile, t]
\frametitle{Sentencias: juntamos lo visto}
Los tipos de sentencia se pueden combinar.\newline

\begin{lstlisting}[language=Python]
>>> listado_numeros = [10,11,12,13]   
>>> # combinamos un for loop y un if
>>> for numero in listado_numeros:
>>>     if numero % 2 == 0:  # se acuerdan del modulo?
>>>         print(numero, "es par")
>>>     else:
>>>         print(numero, "es impar")
10 es par
11 es impar
12 es par
13 es impar
\end{lstlisting} 

\end{frame}

\begin{frame}{Cierre}
\centering
    Dudas?
\end{frame}
